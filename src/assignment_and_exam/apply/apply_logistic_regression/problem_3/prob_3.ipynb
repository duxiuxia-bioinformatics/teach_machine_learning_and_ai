# %% [markdown]
# # Python Solution Notebook: Logistic Regression
#
# **Problem 3: Python Implementation**
# - To generate an imbalanced dataset
# - To fit logistic regression
# - To evaluate the logistic regression model with ROC and PR

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    roc_curve, roc_auc_score,
    precision_recall_curve, average_precision_score,
    confusion_matrix, ConfusionMatrixDisplay
)

# %% [markdown]
# **(A) Generate synthetic gene expression data**

# %%
my_class_sep = 3

# Generate synthetic data
X, y = make_classification(
    n_samples=2000,
    n_features=20,
    n_informative=5,
    n_redundant=2,
    n_repeated=0,
    n_classes=2,
    weights=[0.8, 0.2], # [0.95, 0.05],  # [0.8, 0.2] imbalance: 80% controls, 20% cases
    class_sep=my_class_sep,
    random_state=42
)

# %% [markdown]
# **(B) Split the data into training dataset and testing dataset**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# %% [markdown]
# **(C) Set up a pipeline that will standardize the training data and then fit logistic regression**

# %%
# Set up the pipeline: standardize then logistic regression
lr_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("lr", LogisticRegression(max_iter=2000, solver="lbfgs"))
])

# Train the logistic regression model
lr_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('lr', LogisticRegression(max_iter=2000))])

# %% [markdown]
# **(D) Report the logistic regression model that has been trained above**

# %%
# Examine the model
# coef_ is a 2D numpy array but has only 1 row
print(f'shape of coef_: {lr_pipeline.named_steps["lr"].coef_.shape}')

# intercept_ is a 1D numpy array but has only one item
print(f'shape of intercept_: {lr_pipeline.named_steps["lr"].intercept_.shape}')

# flatten the 2D array into a 1D array for plotting
coef = lr_pipeline.named_steps["lr"].coef_.ravel()
print(f'shape of coef_.ravel(): {coef.shape}')

# get the intercept
intercept = lr_pipeline.named_steps["lr"].intercept_[0]
# Out:
# shape of coef_: (1, 20)
# shape of intercept_: (1,)
# shape of coef_.ravel(): (20,)

# %%
# REPORT the coefficients and intercept

print('\nCoefficients:')
print(coef)

print('\nIntercept:')
print(intercept)
# Out:
# Coefficients:
# [-0.01483638 -0.04330848 -2.83416613 -0.15650217  2.06502713  0.16910774
#  -0.16558682 -0.0338303   0.09071946 -0.76472066  1.30580685 -0.81744318
#  -0.06247894 -1.11061962  0.05375917  0.02871213 -0.05217895 -0.01481072
#  -0.1003726   0.00438928]
#
# Intercept:
# -4.790493630646348

# %%
# plot the coefficients and the corresponding odds increase

fig, axs = plt.subplots(2, 1, figsize=(6, 10))

# plot the coefficients
x_axis_values = list(range(len(coef)))
axs[0].scatter(x_axis_values, coef, color="red")
axs[0].plot([min(x_axis_values), max(x_axis_values)], [0, 0], color='cyan')
axs[0].set_title(r"Coefficients $\beta_j$")
axs[0].set_xlabel(r"$j$")
axs[0].set_ylabel(r"$\beta_j$")

# plot the odds
odds = np.exp(coef)

axs[1].scatter(x_axis_values, odds, color="green")
axs[1].plot([min(x_axis_values), max(x_axis_values)], [1, 1], color='cyan')
axs[1].set_title(r"Increase in odds for each 1-unit increase of $x_j$")
axs[1].set_xlabel(r"$j$")
# Out:
# Text(0.5, 0, '$j$')

# %% [markdown]
# **Interpretation of the coefficients $\beta_j$ for $j = 1, 2, \cdots, d$**
#
# - $\beta_j >0$: increases log-odds and leads to higher probability of $P(y=1|X)$
#
# - $\beta_j <0$: decreases log-odds and leads to lower probability of $P(y=1|X)$
#
# **Interpretation of the odds $e^{\beta_j}$ for $j = 1, 2, \cdots, d$**
# - $e^{\beta_j} > 1:$ increases odds of $P(y=1|X)$
# - $e^{\beta_j} < 1:$ decreases odds of $P(y=1|X)$

# %% [markdown]
# **(E) Predict probabilities**
#
# **Important:** Use the lr_pipeline to scale the test data using the mean and standard deviation obtained from the training data

# %%
# (E.a) Predicted probabilities
proba_test = lr_pipeline.predict_proba(X_test)[:, 1]
print('\nPredicted probabilities of the first 5 samples:')
print(proba_test[0:5])

# plot the probabilities for all of the test samples
fig, ax = plt.subplots()
ax.scatter(list(range(X_test.shape[0])), proba_test, color='red')
ax.plot([0, X_test.shape[0]], [0.5, 0.5], color='cyan')
ax.set_xlabel('test sample index')
ax.set_ylabel('predicted probability')
# Out:
# Predicted probabilities of the first 5 samples:
# [2.46837876e-03 1.44253225e-04 6.21075088e-07 1.21485418e-05
#  7.85005029e-04]
# Text(0, 0.5, 'predicted probability')

# %%
# E.b: Compute the confusion matrix
proba_threshold_list = [0.5, 0.7, 0.9]

for cur_proba_threshold in proba_threshold_list:
    print(f'Probability threshold: {cur_proba_threshold}')
    y_pred = (proba_test >= cur_proba_threshold).astype(int)

    cm = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:\n", cm)

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    tpr = tp / (tp + fn)
    fpr = fp / (fp + tn)
    print("True Positive Rate:", tpr)
    print("False Positive Rate:", fpr, '\n')

# # Plot confusion matrix
# disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp.plot()
# plt.show()
# Out:
# Probability threshold: 0.5
# Confusion Matrix:
#  [[471   7]
#  [  5 117]]
# True Positive Rate: 0.9590163934426229
# False Positive Rate: 0.014644351464435146
#
# Probability threshold: 0.7
# Confusion Matrix:
#  [[474   4]
#  [  7 115]]
# True Positive Rate: 0.9426229508196722
# False Positive Rate: 0.008368200836820083
#
# Probability threshold: 0.9
# Confusion Matrix:
#  [[477   1]
#  [ 24  98]]
# True Positive Rate: 0.8032786885245902
# False Positive Rate: 0.0020920502092050207

# %% [markdown]
# **(F) Plot ROC and compute AUC**

# %%
# ROC and AUC
fpr, tpr, roc_thresh = roc_curve(y_test, proba_test)
auc = roc_auc_score(y_test, proba_test)

plt.figure()
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(f"ROC Curve (AUC = {auc:.2f}), class_sep = {my_class_sep}")

out_file_name = 'ROC_class_sep_' + str(my_class_sep) + '.png'
plt.savefig(out_file_name)

print(f'AUC = {round(auc, 2)}')
# Out:
# AUC = 0.99

# %% [markdown]
# **(G) PLot PR curve and compute the AP**

# %%
# Precision-Recall curve and Average Precision
prec, rec, pr_thresh = precision_recall_curve(y_test, proba_test)
ap = average_precision_score(y_test, proba_test)

plt.figure()
plt.plot(rec, prec)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision–Recall Curve (AP = {ap:.2f}), class_sep = {my_class_sep}")

out_file_name = 'PR_class_sep_' + str(my_class_sep) + '.png'
plt.savefig(out_file_name)

print(f'AP = {round(ap, 2)}')
# Out:
# AP = 0.99

# %% [markdown]
# **(H) Change my_class_sep to 2 and 3 and plot the ROC and PR curves**

# %% [markdown]
# **(I) Why ROC can look “good” while PR looks “bad” under imbalance?**
#
# - ROC uses **FPR**, which divides by the number of negatives (often huge). With many negatives, a model can have small FPR even with many false positives.
# - PR focuses on the **positive class**: precision penalizes false positives directly.
# - In rare-disease settings, PR/AP often gives a more realistic picture of clinical usefulness.
