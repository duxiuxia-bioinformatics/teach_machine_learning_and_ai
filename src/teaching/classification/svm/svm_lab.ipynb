# %% [markdown]
# # Support Vector Machines (SVM) Lab
#
# **Course:** BINF 4211: Applied Data Mining for Bioinformatics
#
# **Goals:**
# - Learn how SVMs work (geometrically + practically),
# - Learn how to train/evaluate them correctly for bioinformatics-style datasets (small *n*, large *d*).

# %% [markdown]
# ## What you will do
# 1. Build intuition for the **maximum-margin** idea (linear SVM)
# 2. Train a linear SVM on a high-dimensional dataset
# 3. Train an RBF-kernel SVM and tune hyperparameters (**C** and **gamma**)
# 4. Evaluate with confusion matrix, ROC, PR curve
# 5. Learn best practices: scaling, leakage avoidance, and model selection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    classification_report,
    roc_curve, auc,
    precision_recall_curve, average_precision_score
)
from sklearn.decomposition import PCA

np.random.seed(7)

# %% [markdown]
# ## Part 1 — Create a toy dataset and train an SVM model to build intuition

# %%
X, y = make_classification(
    n_samples=40,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_repeated=0,
    n_classes=2,
    weights=[0.5, 0.5],
    class_sep=1.0,
    flip_y=0.03,
    random_state=7
)

print('X shape:', X.shape)
print('Class balance:', np.bincount(y))
# Out:
# X shape: (40, 2)
# Class balance: [22 18]

# %%
# check X and y
print('X:')
print(X[:5, :])

print('\ny:')
print(y[:5])
# Out:
# X:
# [[-1.34211899 -1.46970079]
#  [-0.71971171 -0.75826779]
#  [-1.22165323  0.77473841]
#  [ 1.22272811 -1.86853045]
#  [-2.71902266 -0.49958064]]
#
# y:
# [0 0 0 1 0]

# %%
# plot whole simulated data
fig, ax = plt.subplots()
tf = (y==0)
ax.scatter(X[tf, 0], X[tf, 1], c='red', label='class 0')
tf = (y==1)
ax.scatter(X[tf, 0], X[tf, 1], c='blue', label='class 1')
ax.legend()
ax.set_xlabel(r'$x_1$')
ax.set_xlabel(r'$x_2$')
# Out:
# Text(0.5, 0, '$x_2$')

# %%
# split the data into training set and testing set
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    stratify=y,
    random_state=7
)

print('Train:', X_train.shape, ' Test:', X_test.shape)
# Out:
# Train: (30, 2)  Test: (10, 2)

# %%
# Train a SVM model
my_C = 1 # 1.0
svm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='linear', C=my_C))
])
svm_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm', SVC(C=1, kernel='linear'))])

# %%
# check the coefficients and intercept
print(f"coefficients are: {svm_pipeline.named_steps['svm'].coef_}")
w1 = svm_pipeline.named_steps['svm'].coef_[0][0]
w2 = svm_pipeline.named_steps['svm'].coef_[0][1]
b = svm_pipeline.named_steps['svm'].intercept_[0]
print(f"intercept: {b}")
# Out:
# coefficients are: [[ 1.51727113 -0.44274204]]
# intercept: -0.329455089367234

# %%
# check support vectors
print('indices of support vectors:')
print(svm_pipeline.named_steps['svm'].support_)

print('\nsupport vectors:')
support_vectors = svm_pipeline.named_steps['svm'].support_vectors_
print(support_vectors)

print('\nNum of support vectors:')
print(svm_pipeline.named_steps['svm'].n_support_)
# Out:
# indices of support vectors:
# [ 4  9 13 27 28 29  0  5  8 11 17 26]
#
# support vectors:
# [[-0.07191046  1.09936661]
#  [-0.73839566 -1.06693289]
#  [-0.39211109  0.17010848]
#  [-0.63156696 -0.67282069]
#  [ 1.57046401  0.98233185]
#  [ 0.16065856  0.39149829]
#  [ 0.67332478 -0.44701521]
#  [ 1.0213814   0.49880349]
#  [-0.30024725  0.52158799]
#  [-0.45588888  0.665383  ]
#  [ 0.3265597  -1.88431913]
#  [ 0.5700654   0.37947804]]
#
# Num of support vectors:
# [6 6]

# %%
# get the standardized data for plotting
scaler = svm_pipeline.named_steps['scaler']
X_train_scaled = scaler.transform(X_train)

# %%
# show that the support vectors extracted from the scaled training data is exactly what the svm model contains
print(X_train_scaled[svm_pipeline.named_steps['svm'].support_, :])
# Out:
# [[-0.07191046  1.09936661]
#  [-0.73839566 -1.06693289]
#  [-0.39211109  0.17010848]
#  [-0.63156696 -0.67282069]
#  [ 1.57046401  0.98233185]
#  [ 0.16065856  0.39149829]
#  [ 0.67332478 -0.44701521]
#  [ 1.0213814   0.49880349]
#  [-0.30024725  0.52158799]
#  [-0.45588888  0.665383  ]
#  [ 0.3265597  -1.88431913]
#  [ 0.5700654   0.37947804]]

# %%
# unique class labels
print(f"Unique class labels: {np.unique(y_train)}")
pad = 0.5
grid_step = 0.02

# prepare information for plotting the decision boundary
tf = (y_train==0)
x1_class_0_mean = X_train_scaled[tf, 0].mean()
print(x1_class_0_mean)
tf = (y_train==1)
x1_class_1_mean = X_train_scaled[tf, 0].mean()
print(x1_class_1_mean)

# for plotting the decision boundary
x1_min, x1_max = X_train_scaled[:, 0].min() - pad, X_train_scaled[:, 0].max() + pad
x2_min, x2_max = X_train_scaled[:, 1].min() - pad, X_train_scaled[:, 1].max() + pad

x11 = np.arange(x1_min, x1_max, grid_step)
x22_decision_boundary = ((-1.0) * b - w1 * x11 ) / w2
x22_upper_margin = (1.0 + (-1.0) * b - w1 * x11 ) / w2
x22_lower_margin = (-1.0 + (-1.0) * b - w1 * x11 ) / w2
# Out:
# Unique class labels: [0 1]
# -0.6176717200999433
# 0.8077245570537719

# %%
# plot the training data, the hyperplane, and the support vectors
fig, ax = plt.subplots(figsize=(8, 6))

# training data points
tf = (y_train==0)
ax.scatter(X_train_scaled[tf, 0], X_train_scaled[tf, 1], c='red', label='training: class 0')
tf = (y_train==1)
ax.scatter(X_train_scaled[tf, 0], X_train_scaled[tf, 1], c='blue', label='training: class 1')

# decision boundary
ax.plot(x11, x22_decision_boundary, color='green', label=r'$w^Tx + b=0$')

# upper margin
ax.plot(x11, x22_upper_margin, color='blue', label=r'$w^Tx + b=+1$')

# lower margin
ax.plot(x11, x22_lower_margin, color='red', label=r'$w^Tx + b=-1$')

# support vectors
# Highlight support vectors (already in scaled space)
ax.scatter(
    support_vectors[:, 0],
    support_vectors[:, 1],
    s=200,
    facecolors='none',
    edgecolors='black'
)

# w: orthogonal to the hyperplane
ax.plot([0, w1], [0, w2], color='magenta', label=r'$w$')

ax.set_aspect('equal')
ax.set_xlim(x1_min, x1_max)
ax.set_ylim(x2_min, x2_max)
ax.set_xlabel('standardized x1')
ax.set_ylabel('standardized x2')
ax.legend()

# %%
# another way to plot the decision boundary
def plot_svm_boundary_scaled(pipeline, X_train, y_train, pad=0.5, grid_step=0.02):
    """
    Plots decision boundary in the *scaled feature space*.

    Assumes pipeline has:
      - pipeline.named_steps['scaler'] (e.g., StandardScaler)
      - pipeline.named_steps['svm'] (e.g., SVC)
    and that X_train has exactly 2 features (for plotting).
    """
    scaler = pipeline.named_steps['scaler']
    svm = pipeline.named_steps['svm']

    # 1) Scale training data for plotting
    Xs = scaler.transform(X_train)

    # 2) Mesh grid in scaled space
    x1_min, x1_max = Xs[:, 0].min() - pad, Xs[:, 0].max() + pad
    x2_min, x2_max = Xs[:, 1].min() - pad, Xs[:, 1].max() + pad
    x11, x22 = np.meshgrid(
        np.arange(x1_min, x1_max, grid_step),
        np.arange(x2_min, x2_max, grid_step)
    )
    grid = np.c_[x11.ravel(), x22.ravel()]

    # 3) Evaluate decision function on grid
    # decision_function > 0 -> predicted +1 class (for binary)
    Z = svm.decision_function(grid).reshape(x11.shape)

    fig, ax = plt.subplots()
    im = ax.imshow(Z, cmap='viridis')
    fig.colorbar(im, ax=ax, label='value')

    # 4) Plot points
    plt.figure()
    plt.scatter(Xs[:, 0], Xs[:, 1], c=y_train)

    # Decision boundary (0) and margins (-1, +1)
    plt.contour(x11, x22, Z, levels=[-1, 0, 1])

    # Highlight support vectors (already in scaled space)
    plt.scatter(
        svm.support_vectors_[:, 0],
        svm.support_vectors_[:, 1],
        s=200,
        facecolors='none',
        edgecolors='k'
    )

    plt.xlabel("Feature 1 (scaled)")
    plt.ylabel("Feature 2 (scaled)")
    plt.title("SVM decision boundary in scaled space")

plot_svm_boundary_scaled(svm_pipeline, X_train, y_train)

# %% [markdown]
# ## Part 2 — Create a bioinformatics-style dataset
# Bioinformatics often looks like:
# - **small n** (patients) and **large p** (genes/metabolites)
# - noisy features
# - correlated features
# - mild class imbalance
#
# We'll simulate something realistic.

# %%
X, y = make_classification(
    n_samples=1200,          # small number of patients
    n_features=2000,        # large number of genes/features
    n_informative=40,
    n_redundant=40,
    n_repeated=0,
    n_classes=2,
    weights=[0.6, 0.4],
    class_sep=1.0,
    flip_y=0.03,
    random_state=7
)

print('X shape:', X.shape)
print('Class balance:', np.bincount(y))
# Out:
# X shape: (1200, 2000)
# Class balance: [712 488]

# %% [markdown]
# ### Train/test split
# We will hold out a test set. All hyperparameter tuning must happen on the training set only.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    stratify=y,
    random_state=7
)

print('Train:', X_train.shape, ' Test:', X_test.shape)
# Out:
# Train: (900, 2000)  Test: (300, 2000)

# %%
# Train a SVM model
svm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='linear', C=1.0))
])
svm_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('svm', SVC(kernel='linear'))])

# %%
# check the results
print(svm_pipeline.named_steps)
svm_model = svm_pipeline.named_steps['svm']

# print out all the learned items
for attr in dir(svm_model):
    if attr.endswith('_'):
        value = getattr(svm_model, attr)
        print(f"{attr}: {type(value)}")
# Out:
# {'scaler': StandardScaler(), 'svm': SVC(kernel='linear')}
# __abstractmethods__: <class 'frozenset'>
# __annotations__: <class 'dict'>
# __class__: <class 'abc.ABCMeta'>
# __delattr__: <class 'method-wrapper'>
# __dict__: <class 'dict'>
# __dir__: <class 'method'>
# __doc__: <class 'str'>
# __eq__: <class 'method-wrapper'>
# __format__: <class 'builtin_function_or_method'>
# __ge__: <class 'method-wrapper'>
# __getattribute__: <class 'method-wrapper'>
# __getstate__: <class 'method'>
# __gt__: <class 'method-wrapper'>
# __hash__: <class 'method-wrapper'>
# __init__: <class 'method'>
# __init_subclass__: <class 'method'>
# __le__: <class 'method-wrapper'>
# __lt__: <class 'method-wrapper'>
# __module__: <class 'str'>
# __ne__: <class 'method-wrapper'>
# __new__: <class 'builtin_function_or_method'>
# __reduce__: <class 'builtin_function_or_method'>
# __reduce_ex__: <class 'builtin_function_or_method'>
# __repr__: <class 'method'>
# __setattr__: <class 'method-wrapper'>
# __setstate__: <class 'method'>
# __sizeof__: <class 'builtin_function_or_method'>
# __sklearn_clone__: <class 'method'>
# __sklearn_tags__: <class 'method'>
# __str__: <class 'method-wrapper'>
# __subclasshook__: <class 'builtin_function_or_method'>
# __weakref__: <class 'NoneType'>
# _dual_coef_: <class 'numpy.ndarray'>
# _intercept_: <class 'numpy.ndarray'>
# _repr_html_: <class 'method'>
# _repr_mimebundle_: <class 'method'>
# class_weight_: <class 'numpy.ndarray'>
# classes_: <class 'numpy.ndarray'>
# coef_: <class 'numpy.ndarray'>
# dual_coef_: <class 'numpy.ndarray'>
# fit_status_: <class 'int'>
# intercept_: <class 'numpy.ndarray'>
# n_features_in_: <class 'int'>
# n_iter_: <class 'numpy.ndarray'>
# n_support_: <class 'numpy.ndarray'>
# probA_: <class 'numpy.ndarray'>
# probB_: <class 'numpy.ndarray'>
# shape_fit_: <class 'tuple'>
# support_: <class 'numpy.ndarray'>
# support_vectors_: <class 'numpy.ndarray'>

# %%
# check coef_
print(f'coefficients = {svm_model.coef_}')
print(f'intercept = {svm_model.intercept_}')
print(f'support vectors = {svm_model.support_vectors_}')
print(f'support = {svm_model.support_}')
print(f'classes = {svm_model.classes_}')
# Out:
# coefficients = [[-0.06270135  0.0006378   0.00914023 ... -0.00990767  0.0046122
#    0.00964116]]
# intercept = [-0.24708611]
# support vectors = [[ 1.39489102 -0.75649871  0.35847338 ...  1.6638978   1.12880734
#   -0.38729673]
#  [ 1.16370968 -0.72140143 -0.20428921 ...  2.23717941  0.71104729
#   -0.41412989]
#  [ 2.04776636 -0.70784958  0.58108691 ... -0.58442076 -1.74527797
#   -2.14934363]
#  ...
#  [-0.76934277 -0.20767898 -0.28842387 ... -1.85022    -0.49711538
#    1.97878169]
#  [-0.1589641   1.00045204  1.15409852 ...  0.67124511  0.98476179
#   -1.61955606]
#  [-1.9909767   1.02344345 -0.61044712 ...  0.52528883  1.51016034
#   -0.91137563]]
# support = [  0   1   2   6   7   9  10  13  14  18  19  23  24  28  33  34  35  36
#   37  41  42  43  44  45  49  50  51  57  59  61  62  63  67  68  73  75
#   76  77  79  80  81  84  85  87  88  91  92  93  94  96  99 100 102 104
#  105 111 112 115 118 119 120 121 123 134 138 142 146 157 158 160 161 162
#  165 169 170 173 175 176 177 178 179 180 181 183 185 189 191 194 195 197
#  198 201 203 206 210 212 215 216 219 221 224 230 231 233 234 235 236 238
#  242 244 246 250 251 252 253 256 260 261 263 266 270 271 273 275 279 281
#  284 291 293 294 295 301 305 306 311 312 320 321 322 326 328 331 333 334
#  336 340 342 343 344 348 349 351 353 356 357 358 362 363 368 370 371 379
#  380 381 384 386 388 389 395 396 398 400 403 404 405 410 412 414 418 419
#  420 423 424 425 427 433 437 438 442 449 450 452 456 462 463 466 468 469
#  471 472 476 484 493 494 495 496 498 500 503 510 512 513 515 517 520 522
#  523 524 525 527 529 531 535 537 538 539 541 542 544 545 547 551 553 557
#  560 562 566 567 570 572 573 574 576 581 582 583 586 587 588 590 591 592
#  595 598 601 602 604 605 606 608 610 614 615 617 619 621 622 624 625 632
#  633 637 640 643 645 649 650 651 652 653 655 657 661 665 667 671 674 675
#  676 677 678 680 681 685 688 689 690 691 693 694 697 707 708 710 714 716
#  717 719 721 724 725 726 731 733 738 745 747 750 751 752 757 761 762 767
#  768 769 770 774 777 778 779 780 781 788 790 792 795 796 797 804 806 808
#  809 812 815 817 824 825 828 829 832 834 835 847 849 853 855 856 857 859
#  860 862 863 864 867 868 870 871 872 873 875 876 878 882 883 884 888 889
#  892 893 898 899   3   4   5  11  16  17  21  22  25  26  29  31  32  46
#   47  48  52  53  55  56  58  66  69  70  71  72  74  82  83  86  90  98
#  101 109 110 113 114 116 125 131 132 133 135 136 137 140 141 144 147 149
#  151 152 153 164 168 171 186 188 192 196 200 204 207 214 217 218 223 225
#  226 228 229 232 243 245 247 249 255 257 259 264 265 267 268 269 272 274
#  276 277 278 280 283 285 287 288 292 297 299 300 303 309 310 314 315 316
#  318 319 323 324 327 330 332 335 339 341 345 350 352 354 355 359 361 365
#  367 369 372 374 375 376 378 382 393 394 399 402 406 407 413 415 416 417
#  421 422 426 430 431 434 439 440 441 444 445 446 447 453 454 455 460 464
#  473 477 478 480 482 485 486 488 489 490 491 499 501 504 505 506 508 509
#  511 519 521 526 528 533 534 540 543 546 548 550 552 554 556 561 563 564
#  571 577 578 584 585 589 593 596 597 599 600 607 609 611 613 616 626 627
#  628 629 631 634 635 638 639 642 644 647 648 654 656 658 664 666 668 670
#  672 673 682 683 684 686 695 696 699 700 701 705 709 713 715 718 720 723
#  727 728 730 732 735 736 737 739 740 741 742 743 744 746 748 754 755 756
#  758 759 760 763 764 765 772 773 775 776 782 785 786 787 789 793 794 798
#  799 800 801 802 807 810 811 813 816 819 820 821 822 823 826 827 830 831
#  836 837 838 839 840 842 845 846 850 851 852 854 858 865 869 877 879 887
#  891 894 895 896]
# classes = [0 1]

# %% [markdown]
# ## Part 3 — Why scaling matters for SVM
# SVMs are distance-based.
#
# **If features are on different scales, the SVM boundary will be dominated by the largest-scale features.**
#
# We’ll demonstrate by comparing:
# - SVM without scaling
# - SVM with scaling

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

svm_model_raw_data = SVC(kernel='linear', C=1.0)
svm_model_raw_data.fit(X_train, y_train)
pred_raw_data = svm_model_raw_data.predict(X_test)

svm_model_scaled_data = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='linear', C=1.0))
])
svm_model_scaled_data.fit(X_train, y_train)
pred_scaled_data = svm_model_scaled_data.predict(X_test)

print('Accuracy (raw data):', accuracy_score(y_test, pred_raw_data))
print('Accuracy (scaled data):    ', accuracy_score(y_test, pred_scaled_data))

print(f"\nCross validation score (raw data): {cross_val_score(svm_model_raw_data, X, y, cv=10).mean()}")
print(f"Cross validation score (scaled data): {cross_val_score(svm_model_scaled_data, X, y, cv=10).mean()}")
# Out:
# Accuracy (raw data): 0.8
# Accuracy (scaled data):     0.7066666666666667
#
# Cross validation score (raw data): 0.8175000000000001
# Cross validation score (scaled data): 0.7241666666666666

# %% [markdown]
# ## Part 4 — Linear SVM: margin + support vectors
# A linear SVM finds a hyperplane that separates classes while maximizing the margin.
#
# ### Key hyperparameter: **C**
# - Small C → wider margin, more tolerance for errors (more regularization)
# - Large C → narrower margin, tries to classify training points correctly (risk of overfitting)

# %% [markdown]
# ### Cross-validation over C (linear SVM)
# We'll do 5-fold CV on the training set.

# %%
C_grid = [0.01, 0.1, 1, 10, 100]

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=7)

scores = []
for C in C_grid:
    model = Pipeline([
        ('scaler', StandardScaler()),
        ('svm', SVC(kernel='linear', C=C))
    ])
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    scores.append((C, cv_scores.mean(), cv_scores.std()))

df_scores = pd.DataFrame(scores, columns=['C', 'mean_acc', 'std_acc'])
df_scores
# Out:
#         C  mean_acc   std_acc
# 0    0.01  0.751111  0.010184
# 1    0.10  0.751111  0.010184
# 2    1.00  0.751111  0.010184
# 3   10.00  0.751111  0.010184
# 4  100.00  0.751111  0.010184

# %% [markdown]
# ### Plot CV accuracy vs C

# %%
plt.figure(figsize=(6,4))
plt.errorbar(df_scores['C'], df_scores['mean_acc'], yerr=df_scores['std_acc'], fmt='o-')
plt.xscale('log')
plt.xlabel('C (log scale)')
plt.ylabel('CV accuracy')
plt.title('Linear SVM: CV accuracy vs C')
plt.show()

# %% [markdown]
# ### Train the best linear SVM and evaluate on test

# %%
best_C = df_scores.loc[df_scores['mean_acc'].idxmax(), 'C']
print('Best C:', best_C)

best_linear = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='linear', C=best_C, probability=True))
])
best_linear.fit(X_train, y_train)

y_pred = best_linear.predict(X_test)
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm).plot()
plt.title('Linear SVM confusion matrix')
plt.show()
# Out:
# Best C: 0.01
#               precision    recall  f1-score   support
#
#            0       0.72      0.81      0.77       178
#            1       0.67      0.55      0.60       122
#
#     accuracy                           0.71       300
#    macro avg       0.70      0.68      0.69       300
# weighted avg       0.70      0.71      0.70       300

# %% [markdown]
# ## Part 5 — ROC curve and PR curve
# In bioinformatics, **class imbalance is common**.
#
# So we often report:
# - ROC AUC
# - PR AUC (Average Precision)

# %%
y_score = best_linear.predict_proba(X_test)[:, 1]

# ROC
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.plot([0,1],[0,1],'--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC curve (AUC = {roc_auc:.3f})')
plt.show()

# PR
precision, recall, _ = precision_recall_curve(y_test, y_score)
ap = average_precision_score(y_test, y_score)

plt.figure(figsize=(5,5))
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title(f'Precision-Recall curve (AP = {ap:.3f})')
plt.show()

# %% [markdown]
# ## Part 6 — Nonlinear SVM with RBF kernel
# When biology is nonlinear (very common), an RBF kernel can work well.
#
# ### Key hyperparameters
# - **C**: penalty strength
# - **gamma**: how local the decision boundary is
#   - small gamma → smoother boundary
#   - large gamma → very wiggly boundary (overfits)

# %% [markdown]
# ### Grid search for RBF SVM
# We'll tune (C, gamma) with 5-fold CV on the training set.

# %%
param_grid = {
    'svm__C': [0.1, 1, 10, 100],
    'svm__gamma': [1e-4, 1e-3, 1e-2, 1e-1]
}

rbf_pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='rbf', probability=True))
])

grid = GridSearchCV(
    rbf_pipe,
    param_grid=param_grid,
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=7),
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)
print('Best params:', grid.best_params_)
print('Best CV accuracy:', grid.best_score_)
# Out:
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "/opt/anaconda3/envs/teach_ml/lib/python3.11/site.py", line 195, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
#   Traceback (most recent call last):
#     File "/opt/anaconda3/envs/teach_ml/lib/python3.11/site.py", line 195, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /opt/anaconda3/envs/teach_ml/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Best params: {'svm__C': 10, 'svm__gamma': 0.0001}
# Best CV accuracy: 0.76

# %% [markdown]
# ### Evaluate best RBF SVM on test

# %%
best_rbf = grid.best_estimator_
y_pred_rbf = best_rbf.predict(X_test)
print(classification_report(y_test, y_pred_rbf))

cm = confusion_matrix(y_test, y_pred_rbf)
ConfusionMatrixDisplay(cm).plot()
plt.title('RBF SVM confusion matrix')
plt.show()

# %% [markdown]
# ## Part 7 — Visual intuition using PCA (2D projection)
# With 2000 features, we cannot visualize the true hyperplane.
#
# But we can project samples into 2D using PCA to see if the classes separate.

# %%
pca = PCA(n_components=2, random_state=7)
X_train_2d = pca.fit_transform(StandardScaler().fit_transform(X_train))

plt.figure(figsize=(6,5))
plt.scatter(X_train_2d[:,0], X_train_2d[:,1], c=y_train)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA projection of training data (colored by class)')
plt.show()

# %% [markdown]
# ## Part 8 — Common bioinformatics best practices
# ### ✅ Do
# - Always scale features
# - Use a pipeline to prevent leakage
# - Use cross-validation for hyperparameter tuning
# - Report ROC + PR curves when classes are imbalanced
#
# ### ❌ Don't
# - Tune hyperparameters on the test set
# - Perform feature selection on the full dataset before CV
# - Interpret SVM coefficients without thinking about scaling and collinearity

# %% [markdown]
# ## Optional challenge
# Try adding feature selection inside the pipeline:
# - SelectKBest (t-test)
# - then SVM
#
# Compare performance for k = 50, 200, 500.

# %%
from sklearn.feature_selection import SelectKBest, f_classif

pipe_fs = Pipeline([
    ('scaler', StandardScaler()),
    ('select', SelectKBest(score_func=f_classif, k=200)),
    ('svm', SVC(kernel='linear', C=1.0))
])

cv_scores = cross_val_score(pipe_fs, X_train, y_train, cv=5, scoring='accuracy')
print('CV accuracy with feature selection:', cv_scores.mean(), '+/-', cv_scores.std())
